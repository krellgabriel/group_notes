# %%
from datetime import date
import pandas as pd
import boto3
import numpy as np
import os
import sys
import pprint
import pymysql
import json
import os
from io import StringIO, BytesIO
from pathlib import Path
from typing import List
import boto3
import pandas as pd
from tqdm import tqdm
from uuid import UUID

pymysql.install_as_MySQLdb()

s3 = boto3.resource('s3')
s3_client = boto3.client('s3')
bucket_name = 'eleos-ahus'
sessions_name = 'sessions/collide_after_review/'
sessions_analysis = 'sessions/analysis-results-after-review/'
location_s3 = 's3://' + bucket_name + '/' + sessions_name + '{}.collide.csv'

# and set the environment for django connection and collection

os.environ['USER_PATH'] = '/home/gabrielkws/Eleos-Full/eleos'
sys.path.append(os.environ['USER_PATH'])
os.environ["RUN_LOCAL"] = "TRUE"
os.environ["DEBUG"] = "FALSE"

# and now set the connection to rds

from eleos_data_buddy.storage.rds import init_django_connection
init_django_connection(os.environ['USER_PATH'], 'eleos')

from eleos_rest.models.other import *

from eleos_data_buddy.data_analysis.session_analysis_preparation import is_session_valid_for_analysis

from analysis.models import SessionPipeline

from eleos_rest.models import Site, Therapist
from eleos_rest.models.generic_report import GenericGroupIndividualReport,GenericGroupReport
from eleos_rest.models.group_therapy.group_therapy_session import *
from eleos_rest.models.group_therapy.group_therapy_group import *
from eleos_data_buddy.data_analysis.query_database import get_detailed_notes
from eleos_data_buddy.data_analysis.options import get_all_session_suggestions
from eleos_data_buddy.data_analysis.constants import INVALID_ORGANIZATIONS, INVALID_MAIL_WORDS, TECHNOLOGY_TYPES

from eleos_data_buddy.data_analysis.similarity import check_similarity_from_list
from eleos_data_buddy.data_analysis.constants import ELEOS_TEXT_AC
from eleos_data_buddy.data_analysis.options import get_all_session_suggestions
from eleos_data_buddy.data_analysis.text_processing import remove_punctuation_with_condition, add_dot_at_the_end
from eleos_data_buddy.data_analysis.templates import adjust_templates_to_client_preferences
from eleos_data_buddy.storage.s3 import *

from eleos_data_buddy.data_analysis.eleos_text_calculations import get_eleos_suggestions_per_session, find_eleos_text_in_paragraph
from datetime import timedelta

from eleos_data_buddy.data_analysis.note_processing import clean_note
from eleos_data_buddy.data_analysis.query_database import get_notes_by_sessions
from eleos_data_buddy.data_analysis.session_analysis_preparation import is_session_valid_for_analysis
from django.db.models import Q
# Out:
# e

# %% [markdown]
# ## extracting group sessions and individual notes

# %%
INVALID_GROUPS = ['playground', 'sales demo', 'eleos', 'test']
def is_group_valid(group_name):
    """
    :param organization: str
    :return: bool
    """
    if not [i for i in INVALID_GROUPS if i in group_name.lower()]:
        return True

# %%
def filter_group_valid(sessions):
    sessions['group_valid'] = sessions['group'].astype(str).apply(is_group_valid)
    return sessions[sessions['group_valid'] == True]

# %%
def get_group_sessions(start_date, end_date):
    sessions = GroupTherapySession.objects.filter(
        actual_start_ts__gte=start_date,
        actual_start_ts__lt=end_date
    )

    
    g_dict = {}
    for g in sessions:
            patients_list = [patient.name for patient in g.group_therapy_group.patients.all()]
            duration_seconds = (
                (g.actual_end_ts - g.actual_start_ts).total_seconds()
                if (g.actual_start_ts and g.actual_end_ts)
                else None
            )

        
            g_dict[g.id] = {
                'individual_session_id': g.id,
                'group': g.group_therapy_group,
                'session_start': g.actual_start_ts,
                'session_end': g.actual_end_ts,
                #'session duration': (g.actual_end_ts - g.actual_start_ts) if (g.actual_start_ts and g.actual_end_ts) else None,
                'session_duration':duration_seconds,
                'technology': g.technology_used,
                'is_note_confirmed': g.is_note_confirmed,
                'group_therapy_id': g.group_therapy_group_id,
                'is scribe':g.get_is_scribe(),
                'ehr':g.ehr_integration_fields,
                'saved and signed':g.saved_and_signed,
                'is note confirmed':g.is_note_confirmed,
                'therapists':[therapist.name for therapist in g.group_therapy_group.therapists.all()],
                
                
                'patients': patients_list,
                'number of patients':len(patients_list)
                
             
            }

    group_sess = pd.DataFrame(g_dict).T
    group_sessions=filter_group_valid(group_sess)
    return group_sessions

# %%
def is_mail_valid(mail):
    
    
    INVALID_MAIL_WORDS = ['eleos', 'test', 'demo', 'training', 'scribe', 'omri.zohar']
    if '@' in mail and not any([el for el in INVALID_MAIL_WORDS if
                                el in mail.lower()]):
        return True

# %%
def filter_valid_emails(sessions):
    sessions['is_mail_valid'] = sessions['therapist_mail'].astype(str).apply(is_mail_valid)
    return sessions[sessions['is_mail_valid'] == True]

# %%
def get_ind_notes_optimized(group_session, num_fields=30):
    note_parts = [getattr(group_session, f"text_field_{i+1}", None) for i in range(num_fields)]
    note_parts = [part for part in note_parts if part is not None]
    full_note = '. '.join(note_parts)
    return full_note

# %%
def total_info_individual_notes (sessions):

    ind_notes = GenericGroupIndividualReport.objects.filter(group_session_id__in=sessions['individual_session_id'].unique())


    combined_data=[]
    for s in ind_notes:
        
            session_id=s.group_session_id
            note=get_ind_notes_optimized(s)
            combined_data.append({
                'uuid':session_id,
                'individual_session_notes':note,
                'group_session_id': s.group_session.id,
                'therapist_mail':s.therapist,
                'therapist_id':s.therapist_id
            })

    combined_df= pd.DataFrame(combined_data)
    combined_df_filtered = filter_valid_emails(combined_df)
    return combined_df_filtered

# %%
def grouping_notes_per_session (combined_dataframe):
    grouped_notes=combined_dataframe.groupby('uuid')
    all_notes=[]
   
   

    for ga, gb in tqdm(grouped_notes):
        
        phrases= gb['individual_session_notes'].tolist()
        all_notes.append(phrases)

        
    
    group_notes=pd.DataFrame({
        'uuid':grouped_notes.groups.keys(),
        'eleos_notes':all_notes

        
        
    })
    group_notes['num_notes'] = group_notes['eleos_notes'].apply(len)
    return group_notes

# %%
# 1 - extracting group sessions
def group_sessions_individual_notes (start_date, end_date):    
    group_session_basics=get_group_sessions (start_date,end_date)
    #extarcting the  notes of those sessions extracted
    group_sessions_individual_notes=total_info_individual_notes(group_session_basics)
    group_sessions_individual_notes_grouped= grouping_notes_per_session(group_sessions_individual_notes)
    notes_info=pd.merge(group_session_basics,group_sessions_individual_notes_grouped,left_on='individual_session_id',right_on='uuid',how='right')
    columns_added=group_sessions_individual_notes['therapist_mail']
    notes_info['therapist_mail']=columns_added


    return notes_info
    
#start_date=datetime(2022,12, 21)
#end_date=datetime(2023,12, 21)
#resdataframe = group_sessions_individual_notes(start_date, end_date)    
#resdataframe

# %%
def group_sessions_individual_notes_basics (start_date, end_date):    
    group_session_basics=get_group_sessions (start_date,end_date)
    #extarcting the  notes of those sessions extracted
    group_sessions_individual_notes=total_info_individual_notes(group_session_basics)
    group_sessions_individual_notes_grouped= grouping_notes_per_session(group_sessions_individual_notes)
    notes_info=pd.merge(group_session_basics,group_sessions_individual_notes_grouped,left_on='individual_session_id',right_on='uuid',how='left')
    columns_added=group_sessions_individual_notes['therapist_mail']
    notes_info['therapist_mail']=columns_added


    return notes_info

# %%
resdataframe['individual_session_id'].nunique()
# Out:
# 268

# %%
resdataframe.to_csv('/home/gabrielkws/Downloads/resdataframe.csv')

# %% [markdown]
# ## extracting individual suggestions

# %%
def get_individual_eleos_suggestions(session_id_list):
    df_individual = pd.DataFrame()


    
    for uuid in tqdm(session_id_list):
        try:
            uuid = uuid
            path = f's3://eleos-ahus/dev.eleos.health/{uuid}/models/group-individual-summary/model.json'
            b, p = split_s3_path(path)  # Assuming split_s3_path is defined
            a = json_to_df(b, p)  # Assuming json_to_df is defined

            if len(a) > 0:
                a['uuid'] = uuid
                df_individual = pd.concat([df_individual, a])
        
        except:
            pass
            continue

    df_individual=df_individual.rename(columns={'summary':'eleos_suggestions'})
    df_individual = df_individual.drop(columns=['summary_plural'])
    df_individual = df_individual.reset_index(drop=True)
    
    return df_individual

# %%
def grouping_suggestions_per_session (df_individual):
    grouped_sessions=df_individual.groupby('uuid')
    all_suggestions=[]
    speakers_count=[]
   

    for ga, gb in tqdm(grouped_sessions):
        
        phrases= gb['eleos_suggestions'].tolist()
        all_suggestions.append(phrases)

        num_speakers=gb['speaker'].nunique()
        speakers_count.append(num_speakers)

        
    
    group_suggestions=pd.DataFrame({
        'uuid':grouped_sessions.groups.keys(),
        'eleos_individual_suggestions':all_suggestions,
        'speakers':speakers_count
        
        
    })

    group_suggestions['num_individual_suggestions'] = group_suggestions['eleos_individual_suggestions'].apply(len)
    return group_suggestions

# %%
def extract_individual_suggestions (group_sessions_individual_notes):
    session_id_list=group_sessions_individual_notes['uuid'].tolist()
    eleos_suggestions=get_individual_eleos_suggestions(session_id_list)
    #group_sessions_with_suggestions=pd.merge(group_sessions_individual_notes,eleos_suggestions,on='uuid',how='left')
    grouped_suggestions=grouping_suggestions_per_session(eleos_suggestions)
    return grouped_suggestions

#group_individual_suggestions=extract_individual_suggestions(result_dataframe)
#group_individual_suggestions

# %% [markdown]
# ## extracting group notes

# %%
def get_group_notes(group_session, num_fields=29):
    note_parts = [getattr(group_session.genericgroupreport, f"text_field_{i+1}", None) for i in range(num_fields)]
    
    # Filtra los valores no nulos
    note_parts = [part for part in note_parts if part is not None]
    
    full_note = '. '.join(note_parts)
    
    return full_note

# %%
def give_group_notes(sessions_selected):
    group_notes={}
    for s in sessions_selected:
       # session_id=ind_notes.id
        try:
            g_notes=get_group_notes(s)
            group_notes[s]=g_notes
        except:
            pass
    return group_notes

# %%
def total_info_group_notes(sessions):
    combined_data=[]
    for s in sessions:
        session_id=s.id
        notes=get_group_notes(s)
        combined_data.append({
            'session_id':s.id,
            'group_notes':notes,
            'group_id':s.group_therapy_group.id,
            
        })
   
    combined_group_df= pd.DataFrame(combined_data)
    
    return combined_group_df

# %%
def grouping_group_notes_per_group (combined_dataframe):
    
    grouped_notes = combined_dataframe.groupby('session_id')
    
    all_notes = []
    for ga, gb in tqdm(grouped_notes):
        
        phrases = gb['group_notes'].tolist()
        all_notes.append(phrases)
    
    group_notes=pd.DataFrame({
        'session_id':grouped_notes.groups.keys(),
        'eleos_group_notes':all_notes
       
    })

    return group_notes

# %%
def group_notes_group_sessions(start_date,end_date):    
    sessions_group = GroupTherapySession.objects.filter()
    group_notes = give_group_notes(sessions_group)

    df_group_notes = pd.DataFrame(list(group_notes.items()), columns=['session_id', 'group_notes'])
    combined_dataframe_group= total_info_group_notes(group_notes)
    
    group_notes_from_group_sessions=grouping_group_notes_per_group(combined_dataframe_group)
    
    
    return group_notes_from_group_sessions

#group_sessions_group_notes=group_notes_group_sessions(start_date,end_date)
#group_sessions_group_notes

# %%
def group_suggestions (session_id_list):
    df_group = pd.DataFrame()

    for uuid in tqdm(session_id_list):
        try:
            uuid = uuid
        
        
            path_to_group = f's3://eleos-ahus/dev.eleos.health/{uuid}/models/group-summary/model.json'
            b, p = split_s3_path(path_to_group)
            a = json_to_df(b, p)
            if len(a)>0:
                a['session_id'] = uuid
                df_group = pd.concat([df_group, a])  
        except:
            pass
            continue
    
    df_group = df_group.drop(columns=['summary_plural'])
    df_group = df_group.reset_index(drop=True)

    return df_group

#session_id_list=result_dataframe['uuid'].tolist()
#suggest=group_suggestions (session_id_list)
#suggest

# %% [markdown]
# ## suggestions in notes analysis

# %%
def find_eleos_text_in_paragraph(paragraph, eleos_text, ac=ELEOS_TEXT_AC):
    """
    :param paragraph: string
    :param eleos_text: list
    :param ac: float (0-1)
    :return: list of string of eleos generated sentences from text
    """
    ours = []
    for sentence in paragraph:
        if sentence in eleos_text:
            ours.append(sentence)
        else:
            score = check_similarity_from_list(eleos_text, sentence, ac=ac)
            if score:
                ours.append(sentence)
    return ours

# %%
def calculate_eleos_text_percentage_in_note(note, eleos_suggestions):
    """
    :param note: str
    :param section: note section name (key of note dict)
    :param eleos_suggestions: list of strings
    :return: dict
    """
    try:
        note = [s.strip() for s in note.split('.') if s.strip() != '']
        eleos_sentences = find_eleos_text_in_paragraph(paragraph=note, eleos_text=eleos_suggestions)
        note_length = len(note)
        if note_length==0:
            return 0, []
        number_of_eleos_sentences = len(eleos_sentences)
        added_sentences = [x for x in note if x not in eleos_sentences]
        percentage = number_of_eleos_sentences / note_length * 100
        
        return percentage, added_sentences
    except Exception as e:
        print(f"Error on merge:{str(e)}")
        return None, None

# %%
def calculating_suggestions_and_group_notes (suggestions,notes):
    try:
        merged_df_group=pd.merge(notes,suggestions,on='session_id')
        merged_df_group[['session_id','eleos_group_notes']]=notes[['session_id','eleos_group_notes']]
        merged_df_group[['session_id','eleos_group_suggestion_notes']]=suggestions[['session_id','summary']]
        merged_df_group[['eleos_group_suggestion_rate', 'added_group_sentences']]=merged_df_group.apply(lambda row: calculate_eleos_text_percentage_in_note(''.join(row['eleos_group_notes']),
                                                                                       row['eleos_group_suggestion_notes'] 
                                                                                      ),
                            axis=1,
                            result_type='expand')
                                                           
        
        
        return merged_df_group

    except Exception as e:
        print(f"Error on merge:{str(e)}")
        return None
 
  
#df_combined_group=calculating_suggestions_and_group_notes(suggest,group_sessions_group_notes)
#df_combined_group

# %%
def calculating_suggestions_and_notes (suggestions,notes):
    try:
        merged_df=pd.merge(notes,suggestions,on='uuid')
        merged_df[['group_session_id','individual_session_notes','num_individual_notes']]=notes[['individual_session_id','eleos_notes','num_notes']]
        merged_df[['uuid','eleos_individual_suggestions','num_individual_suggestions']]=suggestions[['uuid','eleos_individual_suggestions','num_individual_suggestions']]
        merged_df[['eleos_individual_suggestion_rate','added_group_sentences']]=merged_df.apply(lambda row: calculate_eleos_text_percentage_in_note(''.join(row['individual_session_notes']),
                                                                                       row['eleos_individual_suggestions'] 
                                                                                      ),
                            axis=1,
                            result_type='expand')
                                                           
        
        
        return merged_df

    except Exception as e:
        print(f"Error on merge:{str(e)}")
        return None
#df_combined_individual=calculating_suggestions_and_notes(group_individual_suggestions,result_dataframe)
#df_combined_individual

# %% [markdown]
# ### speakers analysis

# %%
def get_individual_session_speakers_data(notes_suggestions_analysis):
    
    sessions_for_suggestions=notes_suggestions_analysis['session_id'].unique()
    speakers_analysis = pd.DataFrame()

    for uuid in tqdm (sessions_for_suggestions):
        try:
            uuid = uuid
            path = f's3://eleos-ahus/dev.eleos.health/{uuid}/streaming/audio/diarization/model.json'
            b, p = split_s3_path(path)  # Assuming split_s3_path is defined
            a = json_to_df(b, p)  # Assuming json_to_df is defined

            if len(a) > 0:
                a['uuid'] = uuid
                speakers_analysis = pd.concat([speakers_analysis, a])
        
        except :
            pass
            
            continue
    summary_data = speakers_analysis.groupby('uuid').agg(
        total_speakers=('total_speakers','mean'),
        total_talk_time=('total_talk_time','mean'),
        speakers_less_than_threshold=('speakers_less_than_threshold','mean'),
        confidence_therapist_level=('confidence_therapist_level','mean')
    ).reset_index()
    
    
    return summary_data

#speak=get_individual_session_speakers_data(notes_suggestions_analysis)
#speak

# %% [markdown]
# ## final

# %%
# 1 - extracting group sessions
def group_sessions_analysis (start_date, end_date):
    
    result_dataframe=group_sessions_individual_notes (start_date, end_date)   
    group_individual_suggestions=extract_individual_suggestions (result_dataframe)
    group_sessions_group_notes=group_notes_group_sessions(start_date,end_date)
    session_id_list=result_dataframe['uuid'].tolist()
    suggest=group_suggestions (session_id_list)
    individual_notes_and_suggestions= pd.merge(group_individual_suggestions, result_dataframe,on='uuid', how='right')
    group_notes_and_suggestions= pd.merge(group_sessions_group_notes,suggest,on='session_id',how='left')

    df_combined_individual=calculating_suggestions_and_notes(group_individual_suggestions,result_dataframe)
    df_combined_group=calculating_suggestions_and_group_notes(suggest,group_sessions_group_notes)
    columns_to_erase_from_merge=['model_name','text_temp','summary','summary_id']
    notes_suggestions_analysis=pd.merge(df_combined_group,df_combined_individual,left_on='session_id',right_on='individual_session_id',how='left')
    
    notes_suggestions_analysis = notes_suggestions_analysis.drop(columns=columns_to_erase_from_merge)
    speak=get_individual_session_speakers_data(notes_suggestions_analysis)
    sessions_with_report=pd.merge(notes_suggestions_analysis,speak,left_on='session_id',right_on='uuid',how='left')
    sessions_total=group_sessions_individual_notes_basics (start_date, end_date) 
    final_analysis=pd.merge(sessions_total,sessions_with_report,left_on='individual_session_id',right_on='session_id',how='left')

    final_analysis=final_analysis.rename(columns={'individual_session_x':'individual_session','group_x':'group','session_start_x':'session_start','session_end_x':'session_end',
                                                  'session_duration_x':'session_duration_seconds','technology_x':'technology used','is_note_confirmed_x':'is note confirmed',
                                                  'group_therapy_id_x':'group_id','ehr_x':'ehr','therapists_x':'therapists','patients_x':'patients','number of patients_x':'num patients',
                                                  'group_valid_x':'group_valid','eleos_notes_x':'eleos_notes','num_notes_x':'number of notes','therapist_mail_x':'therapist mail'})
                                                  
    final_analysis= final_analysis.drop(['uuid','session_id','individual_session_id_y','group_y','session_start_y','session_end_y',
                                         'is note confirmed_y',	'therapists_y',	'patients_y','number of patients_y','group_valid_y','uuid_x','eleos_notes_y','num_notes_y'], axis=1)
    
    
    
    return final_analysis

#start_date=datetime(2023,11, 21)
#end_date=datetime(2023,12, 21)
#result_dataframe = group_sessions_analysis(start_date, end_date)    
#result_dataframe

# %%
start_date=datetime(2023, 1, 21)
end_date=datetime(2023,12, 21)
result_dataframe = group_sessions_analysis(start_date, end_date)    
result_dataframe
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 6847.00it/s]
# 100%|██████████| 40/40 [00:06<00:00,  6.11it/s]
# 100%|██████████| 23/23 [00:00<00:00, 3134.45it/s]
# 100%|██████████| 87/87 [00:00<00:00, 9950.76it/s]
# 100%|██████████| 40/40 [00:06<00:00,  6.27it/s]
# 100%|██████████| 27/27 [00:03<00:00,  6.80it/s]
# /home/gabrielkws/gabi_first_venv/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1416: RuntimeWarning: DateTimeField GroupTherapySession.actual_start_ts received a naive datetime (2023-01-21 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/gabrielkws/gabi_first_venv/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1416: RuntimeWarning: DateTimeField GroupTherapySession.actual_start_ts received a naive datetime (2023-12-21 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# 100%|██████████| 40/40 [00:00<00:00, 8487.06it/s]
#                   individual_session_id_x  \
# 0    00db3229-1cfb-46fd-a0b3-c767111050d6
# 1    01d854dd-7302-47d0-8bed-070967cd10a3
# 2    02d06daf-0643-41a5-a1c9-47c22395a26b
# 3    02eccf40-d16f-4bc6-a630-918645d6b161
# 4    03e21e29-4c59-48b8-b971-710ff76eb47f
# ..                                    ...
# 263  f8f03006-f16a-45cd-aa04-a1a20379b8f4
# 264  fa43cecb-e9ae-4ae7-b0a8-f52a44120b89
# 265  fb041f1f-68d8-4f65-9a07-0f4492f0994c
# 266  fc535bbe-920f-44ea-8044-5f01ab63d3e8
# 267  fde7b2f6-8f9d-44ac-bb8e-6e2a6538035d
#
#                                                  group  \
# 0    Gaudenzia-Dresher-WG Evening Group - 9ec10cf7-...
# 1    Gaudenzia-Montgomery-Wednesday OP - 28de2a23-1...
# 2    Gaudenzia - Coatesville - Mindfulness Mondays ...
# 3    Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 4    Gaudenzia West Shore PM IOP Group 2940 - 1fa30...
# ..                                                 ...
# 263  Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 264  Gaudenzia - Coatesville - Stages of Change - 4...
# 265  Gaudenzia West Shore PM IOP Group 2940 - 1fa30...
# 266  Gaudenzia-Montgomery-Wednesday OP - 28de2a23-1...
# 267  Gaudenzia West Shore OP Group 4711 - 2d7a2217-...
#
#                 session_start               session_end  \
# 0   2023-09-12 19:56:13+00:00 2023-09-12 21:18:34+00:00
# 1   2023-07-20 21:07:38+00:00 2023-07-22 03:07:37+00:00
# 2   2023-11-20 16:37:23+00:00 2023-11-20 16:39:32+00:00
# 3   2023-11-08 13:59:09+00:00 2023-11-08 17:13:44+00:00
# 4   2023-12-11 21:59:43+00:00 2023-12-11 22:47:14+00:00
# ..                        ...                       ...
# 263 2023-11-01 20:50:10+00:00 2023-11-01 23:31:27+00:00
# 264 2023-10-24 13:57:49+00:00 2023-10-24 15:53:32+00:00
# 265 2023-10-25 20:35:05+00:00 2023-10-25 23:32:13+00:00
# 266 2023-10-02 21:02:26+00:00 2023-10-04 03:02:25+00:00
# 267 2023-11-16 16:55:46+00:00                       NaT
#
#     session_duration_seconds    technology used is note confirmed  \
# 0                     4941.0  zoom_vendors_live             False
# 1                   107999.0  zoom_vendors_live             False
# 2                      129.0  zoom_vendors_live             False
# 3                    11675.0  zoom_vendors_live             False
# 4                     2851.0  zoom_vendors_live             False
# ..                       ...                ...               ...
# 263                   9677.0  zoom_vendors_live             False
# 264                   6943.0  zoom_vendors_live             False
# 265                  10628.0  zoom_vendors_live             False
# 266                 107999.0  zoom_vendors_live             False
# 267                     None  zoom_vendors_live             False
#
#                                  group_id is scribe_x   ehr  ...  \
# 0    9ec10cf7-b2e8-4ea4-bb27-31f1000772bb       False  None  ...
# 1    28de2a23-1972-4e66-bacc-9d733c27421d       False  None  ...
# 2    923762e8-4907-4913-a6e5-657cc114d6d0        True  None  ...
# 3    564115d4-bb6e-4f4e-9e58-3876381ffab1       False  None  ...
# 4    1fa3049d-7e1f-4277-899e-8c6cd49a3c58       False  None  ...
# ..                                    ...         ...   ...  ...
# 263  564115d4-bb6e-4f4e-9e58-3876381ffab1       False  None  ...
# 264  41ed0901-304d-4070-bd9d-c0cfdf30d2d2        True  None  ...
# 265  1fa3049d-7e1f-4277-899e-8c6cd49a3c58       False  None  ...
# 266  28de2a23-1972-4e66-bacc-9d733c27421d       False  None  ...
# 267  2d7a2217-0beb-4930-b84c-b186b64999da       False  None  ...
#
#     group_session_id individual_session_notes num_individual_notes  \
# 0                NaN                      NaN                  NaN
# 1                NaN                      NaN                  NaN
# 2                NaN                      NaN                  NaN
# 3                NaN                      NaN                  NaN
# 4                NaN                      NaN                  NaN
# ..               ...                      ...                  ...
# 263              NaN                      NaN                  NaN
# 264              NaN                      NaN                  NaN
# 265              NaN                      NaN                  NaN
# 266              NaN                      NaN                  NaN
# 267              NaN                      NaN                  NaN
#
#     eleos_individual_suggestion_rate added_group_sentences_y uuid_y  \
# 0                                NaN                     NaN    NaN
# 1                                NaN                     NaN    NaN
# 2                                NaN                     NaN    NaN
# 3                                NaN                     NaN    NaN
# 4                                NaN                     NaN    NaN
# ..                               ...                     ...    ...
# 263                              NaN                     NaN    NaN
# 264                              NaN                     NaN    NaN
# 265                              NaN                     NaN    NaN
# 266                              NaN                     NaN    NaN
# 267                              NaN                     NaN    NaN
#
#     total_speakers  total_talk_time speakers_less_than_threshold  \
# 0              NaN              NaN                          NaN
# 1              NaN              NaN                          NaN
# 2              NaN              NaN                          NaN
# 3              NaN              NaN                          NaN
# 4              NaN              NaN                          NaN
# ..             ...              ...                          ...
# 263            NaN              NaN                          NaN
# 264            NaN              NaN                          NaN
# 265            NaN              NaN                          NaN
# 266            NaN              NaN                          NaN
# 267            NaN              NaN                          NaN
#
#     confidence_therapist_level
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 263                        NaN
# 264                        NaN
# 265                        NaN
# 266                        NaN
# 267                        NaN
#
# [268 rows x 44 columns]

# %%
df_sin_duplicados = result_dataframe.drop_duplicates(subset='session_id')
df_sin_duplicados
# Out:
#                   individual_session_id_x  \
# 0    00db3229-1cfb-46fd-a0b3-c767111050d6
# 6    05728748-b7f3-4ccf-85b3-818de807ff55
# 9    09198d04-1948-422f-b9f2-7afb1fb63b9b
# 14   0ec5edda-0349-4aac-bffa-992a8361b606
# 33   22803474-d6d6-4598-a0a2-87a7608b773b
# 36   2624919d-cdd2-4616-aa41-704b22bc9402
# 38   2748cd17-792d-4873-b43a-468eade30db4
# 40   2aa515ca-f6cf-47bb-b69a-5458b14d2eac
# 54   3d443229-0fe1-460b-a135-2e43254aea73
# 65   4b675d94-4ff3-4312-a9e5-2525d211e23a
# 80   53573ee9-002c-47f1-bf8b-9db4d1ab606b
# 96   60aacfbf-efdf-4aa1-bcc1-365291e4f7f6
# 100  684538db-71ea-48e5-a6b4-8d1a31d82487
# 105  6b1316c5-9ddd-4b6d-8249-229cdef1e481
# 106  6c4ebf77-de4d-4124-922d-6036cc0fa768
# 111  77258d09-cf71-4284-a025-c4579b54c3a0
# 116  79fa23e9-4778-4221-9e6a-782b52ebf43f
# 124  81183f65-0657-4a00-9922-e7d44efd70c5
# 160  9ef6fb0b-eb76-4ea5-8fc1-c3454f2dddf1
# 164  a0117b12-feb4-486e-ba83-f5687b02c192
# 183  afc69601-60c1-49c0-9fa3-20f161fd55d5
# 184  b02d83f0-3145-4efa-ac10-c675bdcb26fa
# 187  b2eae694-4279-46aa-89e6-25b9b37ad71c
# 198  b6819d13-600b-48a3-84d5-075267ead036
# 216  cbc2defc-bf5b-421e-8ed9-e952a16625b6
# 242  e25dbf43-b1b1-433a-a5a8-1d4e02464235
# 259  f291c802-cd84-4262-8065-885200657107
# 260  f2baeaa9-f1b5-400f-99ab-45b971cb6e48
#
#                                                group_x  \
# 0    Gaudenzia-Dresher-WG Evening Group - 9ec10cf7-...
# 6    Gaudenzia West Shore PM IOP Group 2940 - 1fa30...
# 9    APN Currant Process Group - d1437136-15de-40d3...
# 14   Gaudenzia West Shore OP Group 4711 - 2d7a2217-...
# 33   Gaudenzia West Shore OP Group 4711 - 2d7a2217-...
# 36   Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 38   Gaudenzia West Shore OP Group 4711 - 2d7a2217-...
# 40   Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 54   Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 65   Gaudenzia West Shore PM IOP Group 2940 - 1fa30...
# 80   APN Chalet Process Group - 4af5898a-82f2-4f16-...
# 96   Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 100  Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 105  Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 106  Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 111  Gaudenzia West Shore PM IOP Group 2940 - 1fa30...
# 116  Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 124  Gaudenzia - Coatesville - Steps to Recovery - ...
# 160  Gaudenzia - Coatesville - Steps to Recovery - ...
# 164  Gaudenzia West Shore OP Group 4711 - 2d7a2217-...
# 183  Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 184  Gaudenzia West Shore PM IOP Group 2940 - 1fa30...
# 187  Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 198  Gaudenzia West Shore PM IOP Group 2940 - 1fa30...
# 216  Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 242  Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 259  Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# 260  Gaudenzia West Shore OP Group 4711 - 2d7a2217-...
#
#               session_start_x             session_end_x session duration_x  \
# 0   2023-09-12 19:56:13+00:00 2023-09-12 21:18:34+00:00    0 days 01:22:21
# 6   2023-10-23 20:59:49+00:00 2023-10-23 23:28:48+00:00    0 days 02:28:59
# 9   2023-12-13 16:57:52+00:00 2023-12-13 18:49:20+00:00    0 days 01:51:28
# 14  2023-12-07 17:03:35+00:00 2023-12-07 18:37:45+00:00    0 days 01:34:10
# 33  2023-12-14 16:50:35+00:00 2023-12-14 18:43:17+00:00    0 days 01:52:42
# 54                                                 NaN                  NaN
# 65   [The 12 Noon OP Group is a hybrid group that m...                  1.0
# 80   [In today's group all members checked in. Toda...                  3.0
# 96                                                 NaN                  NaN
# 100  [The group therapy session discussed the topic...                  2.0
# 105                                                 []                  1.0
# 106                                                NaN                  NaN
# 111  [There were 5 clients in group tonight all in-...                  2.0
# 116  [In therapy session, the client expressed frus...                  1.0
# 124  [Micheal shared comments to the Life History o...                  1.0
# 160  [The client shared their story of growing up a...                  1.0
# 164  [Client did not show for the group. Client did...                  1.0
# 183  [In today's group all members checked in. The ...                  2.0
# 184  [The group therapy session discussed the impac...                  1.0
# 187  [In IOP group today we used MI to determine va...                  1.0
# 198  [The Noon OP Group is a hybrid, consisting of ...                  1.0
# 216  [AM IOP Group is a hybrid group from 9 am to 1...                  1.0
# 242  [Group Members checked in by detailing their d...                  1.0
# 259  [The group therapy session discussed the effec...                  1.0
# 260  [This group session began with a check-in. Eac...                  1.0
#
#     eleos_individual_suggestion_rate  \
# 0                                NaN
# 6                                0.0
# 9                                0.0
# 14                               0.0
# 33                               0.0
# 36                               NaN
# 38                               NaN
# 40                               0.0
# 54                               NaN
# 65                               0.0
# 80                               0.0
# 96                               NaN
# 100                              0.0
# 105                              0.0
# 106                              NaN
# 111                              0.0
# 116                              0.0
# 124                              0.0
# 160                              0.0
# 164                              0.0
# 183                              0.0
# 184                              0.0
# 187                              0.0
# 198                              0.0
# 216                              0.0
# 242                              0.0
# 259                              0.0
# 260                              0.0
#
#                                added_group_sentences_y  \
# 0                                                  NaN
# 6    [The group therapy session discussed the topic...
# 9    [The client reflected on how emotional struggl...
# 14   [The 12 Noon OP Group is a hybrid group that m...
# 33   [The 12 noon OP group is a hybrid group that m...
# 36                                                 NaN
# 38                                                 NaN
# 40   [The AM IOP Group is a hybrid group that meets...
# 54                                                 NaN
# 65   [The 12 Noon OP Group is a hybrid group that m...
# 80   [In today's group all members checked in, Toda...
# 96                                                 NaN
# 100  [The group therapy session discussed the topic...
# 105                                                 []
# 106                                                NaN
# 111  [There were 5 clients in group tonight all in-...
# 116  [In therapy session, the client expressed frus...
# 124  [Micheal shared comments to the Life History o...
# 160  [The client shared their story of growing up a...
# 164  [Client did not show for the group, Client did...
# 183  [In today's group all members checked in, The ...
# 184  [The group therapy session discussed the impac...
# 187  [In IOP group today we used MI to determine va...
# 198  [The Noon OP Group is a hybrid, consisting of ...
# 216  [AM IOP Group is a hybrid group from 9 am to 1...
# 242  [Group Members checked in by detailing their d...
# 259  [The group therapy session discussed the effec...
# 260  [This group session began with a check-in, Eac...
#
#                                    uuid_y total_speakers total_talk_time  \
# 0                                     NaN            NaN             NaN
# 6                                     NaN            NaN             NaN
# 9    09198d04-1948-422f-b9f2-7afb1fb63b9b           15.0          101.93
# 14   0ec5edda-0349-4aac-bffa-992a8361b606            7.0           81.76
# 33   22803474-d6d6-4598-a0a2-87a7608b773b            9.0           92.40
# 36                                    NaN            NaN             NaN
# 38   2748cd17-792d-4873-b43a-468eade30db4            5.0           34.00
# 40                                    NaN            NaN             NaN
# 54                                    NaN            NaN             NaN
# 65                                    NaN            NaN             NaN
# 80   53573ee9-002c-47f1-bf8b-9db4d1ab606b           13.0           87.61
# 96                                    NaN            NaN             NaN
# 100                                   NaN            NaN             NaN
# 105                                   NaN            NaN             NaN
# 106                                   NaN            NaN             NaN
# 111                                   NaN            NaN             NaN
# 116                                   NaN            NaN             NaN
# 124                                   NaN            NaN             NaN
# 160                                   NaN            NaN             NaN
# 164                                   NaN            NaN             NaN
# 183                                   NaN            NaN             NaN
# 184                                   NaN            NaN             NaN
# 187                                   NaN            NaN             NaN
# 198                                   NaN            NaN             NaN
# 216                                   NaN            NaN             NaN
# 242                                   NaN            NaN             NaN
# 259                                   NaN            NaN             NaN
# 260                                   NaN            NaN             NaN
#
#      speakers_less_than_threshold confidence_therapist_level
# 0                             NaN                        NaN
# 6                             NaN                        NaN
# 9                            10.0                   0.745183
# 14                            1.0                   0.880418
# 33                            2.0                   0.707300
# 36                            NaN                        NaN
# 38                            1.0                   0.832041
# 40                            NaN                        NaN
# 54                            NaN                        NaN
# 65                            NaN                        NaN
# 80                            4.0                   0.833825
# 96                            NaN                        NaN
# 100                           NaN                        NaN
# 105                           NaN                        NaN
# 106                           NaN                        NaN
# 111                           NaN                        NaN
# 116                           NaN                        NaN
# 124                           NaN                        NaN
# 160                           NaN                        NaN
# 164                           NaN                        NaN
# 183                           NaN                        NaN
# 184                           NaN                        NaN
# 187                           NaN                        NaN
# 198                           NaN                        NaN
# 216                           NaN                        NaN
# 242                           NaN                        NaN
# 259                           NaN                        NaN
# 260                           NaN                        NaN
#
# [28 rows x 58 columns]

# %%
result_dataframe.total_speakers.mean()
# Out:
# 9.8

# %%
def calculate_eleos_text_percentage_in_note_TEST(note, eleos_suggestions):
    """
    :param note: str
    :param section: note section name (key of note dict)
    :param eleos_suggestions: list of strings
    :return: dict
    """
    try:
        note = [s.strip() for s in note.split('.') if s.strip() != '']
        eleos_sentences = find_eleos_text_in_paragraph(paragraph=note, eleos_text=eleos_suggestions)
        note_length = len(note)
        if note_length==0:
            return 0, []
        number_of_eleos_sentences = len(eleos_sentences)
        added_sentences = [x for x in note if x not in eleos_sentences]
        percentage = number_of_eleos_sentences / note_length * 100
        
        return percentage, added_sentences
    except Exception as e:
        print(f"Error on merge:{str(e)}")
        return None, None

# %%
test=result_dataframe.apply(lambda row: calculate_eleos_text_percentage_in_note_TEST(''.join(row['eleos_group_notes']),
                                                                                       row['eleos_group_suggestion_notes'] 
                                                                                      ),
                            axis=1,
                            result_type='expand')
test
# Out:
#       0                                                  1
# 0   0.0  [The focus of the group therapy session was on...
# 1   0.0                                                 []
# 2   0.0  [The group therapy session discussed the topic...
# 3   0.0  [Clinician utilized a psychodynamic approach t...
# 4   0.0  [The focus of the group therapy session was on...
# 5   0.0  [The 12 Noon OP Group is a hybrid group that m...
# 6   0.0                                                 []
# 7   0.0                                                 []
# 8   0.0  [The focus of the group therapy session was on...
# 9   0.0  [The 12 noon OP group is a hybrid group that m...
# 10  0.0  [The AM IOP Group is a hybrid group that meets...
# 11  0.0  [The 12 Noon OP Group is a hybrid group that m...
# 12  0.0                                                 []
# 13  0.0  [In today's group all members checked in, Toda...
# 14  0.0  [The group therapy session discussed the topic...
# 15  0.0  [The group therapy session discussed the topic...
# 16  0.0  [The group therapy session discussed the topic...
# 17  0.0                                                 []
# 18  0.0  [The group therapy session discusses the impor...
# 19  0.0  [The topic of self-care and the importance of ...
# 20  0.0                                                 []
# 21  0.0  [The group therapy session discussed the topic...
# 22  0.0  [The group therapy session discussed the topic...
# 23  0.0  [The group, The 12 Noon OP group, is a hybrid ...
# 24  0.0  [This group session began with a check-in, Eac...
# 25  0.0                                                 []
# 26  0.0  [There were 3 clients in group tonight all in-...

# %%
result_dataframe['uuid'].nunique()
# Out:
# 40

# %%
chen_list = pd.read_csv('/home/gabrielkws/Documents/chen group sessions.csv')
chen_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   #               50 non-null     int64
#  1   id              50 non-null     object
#  2   therapist_mail  50 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB

# %%
#60aacfbf-efdf-4aa1-bcc1-365291e4f7f6
#05728748-b7f3-4ccf-85b3-818de807ff55
def format_code(code):
    
    code_str = str(code)
    return f'{code_str[:8]}-{code_str[8:12]}-{code_str[12:16]}-{code_str[16:20]}-{code_str[20:]}'

chen_list['uuid']=chen_list['id'].apply(format_code)
chen_list
# Out:
#      #                                id             therapist_mail  \
# 0    1  05728748b7f34ccf85b3818de807ff55       mirwin@gaudenzia.org
# 1    2  09198d041948422fb9f27afb1fb63b9b            sdaniel@apn.com
# 2    3  2aa515caf6cf47bbb69a5458b14d2eac      lknoche@gaudenzia.org
# 3    4  4398946ecc7c4662ae85d3b0cd3d0c44     ntomczak@gaudenzia.org
# 4    5  6b1316c59ddd4b6d8249229cdef1e481       jbabil@gaudenzia.org
# 5    6  77258d09cf714284a025c4579b54c3a0       mirwin@gaudenzia.org
# 6    7  81183f6506574a009922e7d44efd70c5     ntomczak@gaudenzia.org
# 7    8  9ef6fb0beb764ea58fc1c3454f2dddf1     ntomczak@gaudenzia.org
# 8    9  a0b95acdaed8425fa3fa4e1cedb20ffb     ntomczak@gaudenzia.org
# 9   10  afc6960160c149c09fa320f161fd55d5      lknoche@gaudenzia.org
# 10  11  b6819d13600b48a384d5075267ead036       mirwin@gaudenzia.org
# 11  12  cbc2defcbf5b421e8ed9e952a16625b6       jbabil@gaudenzia.org
# 12  13  cc85c60a7085480f8f5172b204b69139  tbuckwalter@gaudenzia.org
# 13  14  e25dbf43b1b1433aa5a81d4e02464235       jbabil@gaudenzia.org
# 14  15  f291c802cd8442628065885200657107       jbabil@gaudenzia.org
# 15  16  29464b2095e94563bdcb131047d6f3a7     aschmitt@gaudenzia.org
# 16  17  50d8a1a47f564c09b7287b72305c46be     ntomczak@gaudenzia.org
# 17  18  2624919dcdd24616aa41704b22bc9402     tharbold@gaudenzia.org
# 18  19  60aacfbfefdf4aa1bcc1365291e4f7f6     tharbold@gaudenzia.org
# 19  20  6544ec8c01a64a688c0729d46c9e18df  tbuckwalter@gaudenzia.org
# 20  21  6cf9dedffb1f4689a1c200b17d6f07e8       jbabil@gaudenzia.org
# 21  22  a0117b12feb4486eba83f5687b02c192       jbabil@gaudenzia.org
# 22  23  c2a9212cc7f342598075c97a7b23c829     tharbold@gaudenzia.org
# 23  24  774e7ac1e963491d9e0c5f3700d52a09      lknoche@gaudenzia.org
# 24  25  951005cffbe44ba787f43e37c1e8c615       jbabil@gaudenzia.org
# 25  26  0ec5edda03494aacbffa992a8361b606       jbabil@gaudenzia.org
# 26  27  2748cd17792d4873b43a468eade30db4       jbabil@gaudenzia.org
# 27  28  3d4432290fe1460ba1352e43254aea73     tharbold@gaudenzia.org
# 28  29  4b675d944ff34312a9e52525d211e23a        nweir@gaudenzia.org
# 29  30  5d3368d8ccb34e7baa5f12d6ad040532       jbabil@gaudenzia.org
# 30  31  684538db71ea48e5a6b48d1a31d82487      lknoche@gaudenzia.org
# 31  32  6c4ebf77de4d4124922d6036cc0fa768      lknoche@gaudenzia.org
# 32  33  71353e6a81ab4530adcdc41b8dffcaf4       jbabil@gaudenzia.org
# 33  34  b2eae694427946aa89e625b9b37ad71c       jbabil@gaudenzia.org
# 34  35  c171a0d5fdf54cfe8865955069c4abc9  tbuckwalter@gaudenzia.org
# 35  36  fb041f1f68d84f659a070f4492f0994c       mirwin@gaudenzia.org
# 36  37  4301b70a89054861a01a7c5e70a27ae3       jbabil@gaudenzia.org
# 37  38  e826c80854f7494fb51ca6b4722f1d67     ntomczak@gaudenzia.org
# 38  39  22803474d6d64598a0a287a7608b773b       jbabil@gaudenzia.org
# 39  40  53573ee9002c47f1bf8b9db4d1ab606b            gbeatty@apn.com
# 40  41  79fa23e9477842219e6a782b52ebf43f       mirwin@gaudenzia.org
# 41  42  9e53836279fe469092530f3b291a8e0f  tbuckwalter@gaudenzia.org
# 42  43  a825c2e857b1405aa6a02aa95fb04489       jbabil@gaudenzia.org
# 43  44  b02d83f031454efaac10c675bdcb26fa        nweir@gaudenzia.org
# 44  45  f2baeaa9f1b5400f99ab45b971cb6e48       jbabil@gaudenzia.org
# 45  46  fa43cecbe9ae4ae7b0a8f52a44120b89       avacca@gaudenzia.org
# 46  47  4ccdc434e5684965b309eb71c3d69082       jbabil@gaudenzia.org
# 47  48  653d7fb43e78407397856af548647ab9     ntomczak@gaudenzia.org
# 48  49  a306a4279e94486f97c0fbdab0f8003c       jbabil@gaudenzia.org
# 49  50  ce3ef9bd2c374cb68cb0d9e25da2f6bf       mirwin@gaudenzia.org
#
#                                     uuid
# 0   05728748-b7f3-4ccf-85b3-818de807ff55
# 1   09198d04-1948-422f-b9f2-7afb1fb63b9b
# 2   2aa515ca-f6cf-47bb-b69a-5458b14d2eac
# 3   4398946e-cc7c-4662-ae85-d3b0cd3d0c44
# 4   6b1316c5-9ddd-4b6d-8249-229cdef1e481
# 5   77258d09-cf71-4284-a025-c4579b54c3a0
# 6   81183f65-0657-4a00-9922-e7d44efd70c5
# 7   9ef6fb0b-eb76-4ea5-8fc1-c3454f2dddf1
# 8   a0b95acd-aed8-425f-a3fa-4e1cedb20ffb
# 9   afc69601-60c1-49c0-9fa3-20f161fd55d5
#  '3d443229-0fe1-460b-a135-2e43254aea73',
#  '4301b70a-8905-4861-a01a-7c5e70a27ae3',
#  '4398946e-cc7c-4662-ae85-d3b0cd3d0c44',
#  '4b675d94-4ff3-4312-a9e5-2525d211e23a',
#  '4ccdc434-e568-4965-b309-eb71c3d69082',
#  '50d8a1a4-7f56-4c09-b728-7b72305c46be',
#  '53573ee9-002c-47f1-bf8b-9db4d1ab606b',
#  '5d3368d8-ccb3-4e7b-aa5f-12d6ad040532',
#  '60aacfbf-efdf-4aa1-bcc1-365291e4f7f6',
#  '653d7fb4-3e78-4073-9785-6af548647ab9',
#  '6544ec8c-01a6-4a68-8c07-29d46c9e18df',
#  '684538db-71ea-48e5-a6b4-8d1a31d82487',
#  '6b1316c5-9ddd-4b6d-8249-229cdef1e481',
#  '6c4ebf77-de4d-4124-922d-6036cc0fa768',
#  '6cf9dedf-fb1f-4689-a1c2-00b17d6f07e8',
#  '71353e6a-81ab-4530-adcd-c41b8dffcaf4',
#  '77258d09-cf71-4284-a025-c4579b54c3a0',
#  '774e7ac1-e963-491d-9e0c-5f3700d52a09',
#  '79fa23e9-4778-4221-9e6a-782b52ebf43f',
#  '81183f65-0657-4a00-9922-e7d44efd70c5',
#  '951005cf-fbe4-4ba7-87f4-3e37c1e8c615',
#  '9e538362-79fe-4690-9253-0f3b291a8e0f',
#  '9ef6fb0b-eb76-4ea5-8fc1-c3454f2dddf1',
#  'a0117b12-feb4-486e-ba83-f5687b02c192',
#  'a0b95acd-aed8-425f-a3fa-4e1cedb20ffb',
#  'a306a427-9e94-486f-97c0-fbdab0f8003c',
#  'a825c2e8-57b1-405a-a6a0-2aa95fb04489',
#  'afc69601-60c1-49c0-9fa3-20f161fd55d5',
#  'b02d83f0-3145-4efa-ac10-c675bdcb26fa',
#  'b2eae694-4279-46aa-89e6-25b9b37ad71c',
#  'b6819d13-600b-48a3-84d5-075267ead036',
#  'c171a0d5-fdf5-4cfe-8865-955069c4abc9',
#  'c2a9212c-c7f3-4259-8075-c97a7b23c829',
#  'cbc2defc-bf5b-421e-8ed9-e952a16625b6',
#  'cc85c60a-7085-480f-8f51-72b204b69139',
#  'ce3ef9bd-2c37-4cb6-8cb0-d9e25da2f6bf',
#  'e25dbf43-b1b1-433a-a5a8-1d4e02464235',
#  'e826c808-54f7-494f-b51c-a6b4722f1d67',
#  'f291c802-cd84-4262-8065-885200657107',
#  'f2baeaa9-f1b5-400f-99ab-45b971cb6e48',
#  'fa43cecb-e9ae-4ae7-b0a8-f52a44120b89',
#  'fb041f1f-68d8-4f65-9a07-0f4492f0994c'}

# %%
res=group_sessions_individual_notes (start_date, end_date)
res
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 9635.43it/s]
#                    individual_session_id  \
# 0   05728748-b7f3-4ccf-85b3-818de807ff55
# 1   09198d04-1948-422f-b9f2-7afb1fb63b9b
# 2   0ec5edda-0349-4aac-bffa-992a8361b606
# 3   22803474-d6d6-4598-a0a2-87a7608b773b
# 4   2624919d-cdd2-4616-aa41-704b22bc9402
# 5   2748cd17-792d-4873-b43a-468eade30db4
Elise Narkiewicz, Keri Wintersteen, Laila Eng...
# 1                                      [Scott Daniel]
# 2   [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 3   [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 4   [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 5   [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 6   [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 7   [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 8   [Angel Sargent, Nicholas Tomczak, Barry Trout,...
# 9   [Elise Narkiewicz, Keri Wintersteen, Laila Eng...
# 10                                                 []
# 11  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 12  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 13  [Nicholas Tomczak, Barry Trout, Todd Buckwalte...
# 14  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 15  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 16  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 17  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 18  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 19  [Elise Narkiewicz, Keri Wintersteen, Laila Eng...
# 20  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 21  [Angel Sargent, Nicholas Tomczak, Barry Trout,...
# 22  [Nicholas Tomczak, Barry Trout, Todd Buckwalte...
# 23  [Angel Sargent, Nicholas Tomczak, Barry Trout,...
# 24  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 25  [Angel Sargent, Nicholas Tomczak, Barry Trout,...
# 26  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 27  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 28  [Elise Narkiewicz, Keri Wintersteen, Laila Eng...
# 29  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 30  [Elise Narkiewicz, Keri Wintersteen, Laila Eng...
# 31  [Nicholas Tomczak, Barry Trout, Todd Buckwalte...
# 32  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 33  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 34  [Nicholas Tomczak, Barry Trout, Todd Buckwalte...
# 35  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 36  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 37  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# 38  [Nicholas Tomczak, Barry Trout, Todd Buckwalte...
# 39  [Elise Narkiewicz, Keri Wintersteen, Laila Eng...
#
#                                              patients number of patients  \
# 0      [Angela Kline, Bradley Biller, William Nalley]                  3
# 1   [Brandon C Burns, Brandon Yeubanks, Fitz Patri...                  3
# 2   [Adriana Rivera-Colon, Allazzar Cato, Brian Ad...                 10
# 3   [Adriana Rivera-Colon, Allazzar Cato, Brian Ad...                 10
# 4   [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 5   [Adriana Rivera-Colon, Allazzar Cato, Brian Ad...                 10
# 6   [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 7   [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 8   [Bryan Lyons, Dyisha Jackson, Hassan Dandridge...                  6
# 9      [Angela Kline, Bradley Biller, William Nalley]                  3
# 10                                      [Brad Parker]                  1
# 11  [Adriana Rivera-Colon, Allazzar Cato, Brian Ad...                 10
# 12  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 13  [Bryan Lyons, Charles Gorman, Noel Lourido, Se...                  4
# 14  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 15  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 16  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 17  [Adriana Rivera-Colon, Allazzar Cato, Brian Ad...                 10
# 18  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 19     [Angela Kline, Bradley Biller, William Nalley]                  3
# 20  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 21  [Bryan Lyons, Dyisha Jackson, Hassan Dandridge...                  6
# 22  [Bryan Lyons, Charles Gorman, Noel Lourido, Se...                  4
# 23  [Bryan Lyons, Dyisha Jackson, Hassan Dandridge...                  6
# 24  [Adriana Rivera-Colon, Allazzar Cato, Brian Ad...                 10
# 25  [Bryan Lyons, Dyisha Jackson, Hassan Dandridge...                  6
# 26  [Adriana Rivera-Colon, Allazzar Cato, Brian Ad...                 10
# 27  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 28     [Angela Kline, Bradley Biller, William Nalley]                  3
# 29  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 30     [Angela Kline, Bradley Biller, William Nalley]                  3
# 31  [Bryan Lyons, Charles Gorman, Noel Lourido, Se...                  4
# 32  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 33  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 34  [Bryan Lyons, Charles Gorman, Noel Lourido, Se...                  4
# 35  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 36  [000000000, Adriana Rivera-Colon, Billy Mentze...                 18
# 37  [Adriana Rivera-Colon, Allazzar Cato, Brian Ad...                 10
# 38  [Bryan Lyons, Charles Gorman, Noel Lourido, Se...                  4
# 39     [Angela Kline, Bradley Biller, William Nalley]                  3
#
#                                     uuid  \
# 0   05728748-b7f3-4ccf-85b3-818de807ff55
# 1   09198d04-1948-422f-b9f2-7afb1fb63b9b
# 2   0ec5edda-0349-4aac-bffa-992a8361b606
# 3   22803474-d6d6-4598-a0a2-87a7608b773b
# 4   2624919d-cdd2-4616-aa41-704b22bc9402
# 5   2748cd17-792d-4873-b43a-468eade30db4
# 6   2aa515ca-f6cf-47bb-b69a-5458b14d2eac
# 7   3d443229-0fe1-460b-a135-2e43254aea73
# 8   4398946e-cc7c-4662-ae85-d3b0cd3d0c44
# 9   4b675d94-4ff3-4312-a9e5-2525d211e23a
# 10  53573ee9-002c-47f1-bf8b-9db4d1ab606b
# 11  5d3368d8-ccb3-4e7b-aa5f-12d6ad040532
# 12  60aacfbf-efdf-4aa1-bcc1-365291e4f7f6
# 13  6544ec8c-01a6-4a68-8c07-29d46c9e18df
# 14  684538db-71ea-48e5-a6b4-8d1a31d82487
# 15  6b1316c5-9ddd-4b6d-8249-229cdef1e481
# 16  6c4ebf77-de4d-4124-922d-6036cc0fa768
# 17  6cf9dedf-fb1f-4689-a1c2-00b17d6f07e8
# 18  71353e6a-81ab-4530-adcd-c41b8dffcaf4
# 19  77258d09-cf71-4284-a025-c4579b54c3a0
# 20  79fa23e9-4778-4221-9e6a-782b52ebf43f
# 21  81183f65-0657-4a00-9922-e7d44efd70c5
# 22  9e538362-79fe-4690-9253-0f3b291a8e0f
# 23  9ef6fb0b-eb76-4ea5-8fc1-c3454f2dddf1
# 24  a0117b12-feb4-486e-ba83-f5687b02c192
# 25  a0b95acd-aed8-425f-a3fa-4e1cedb20ffb
# 26  a825c2e8-57b1-405a-a6a0-2aa95fb04489
# 27  afc69601-60c1-49c0-9fa3-20f161fd55d5
# 28  b02d83f0-3145-4efa-ac10-c675bdcb26fa
# 29  b2eae694-4279-46aa-89e6-25b9b37ad71c
# 30  b6819d13-600b-48a3-84d5-075267ead036
# 31  c171a0d5-fdf5-4cfe-8865-955069c4abc9
# 32  c2a9212c-c7f3-4259-8075-c97a7b23c829
# 33  cbc2defc-bf5b-421e-8ed9-e952a16625b6
# 34  cc85c60a-7085-480f-8f51-72b204b69139
# 35  e25dbf43-b1b1-433a-a5a8-1d4e02464235
# 36  f291c802-cd84-4262-8065-885200657107
# 37  f2baeaa9-f1b5-400f-99ab-45b971cb6e48
# 38  fa43cecb-e9ae-4ae7-b0a8-f52a44120b89
# 39  fb041f1f-68d8-4f65-9a07-0f4492f0994c
#
#                                           eleos_notes  num_notes  \
# 0   [The group therapy session discussed the topic...          1
# 1   [The client reflected on how emotional struggl...          2
# 2   [The 12 Noon OP Group is a hybrid group that m...          1
# 3   [The 12 noon OP group is a hybrid group that m...          3
# 4   [The AM IOP Group is a hybrid group that meets...          3
# 5   [The 12 Noon OP Group is a hybrid group that m...          1
# 6   [In today's group all members checked in. Toda...          3
# 7   [The group therapy session discussed the topic...          2
# 8                                                  []          1
# 9   [There were 5 clients in group tonight all in-...          2
# 10  [In therapy session, the client expressed frus...          1
# 11  [Micheal shared comments to the Life History o...          1
# 12  [The client shared their story of growing up a...          1
# 13  [Client did not show for the group. Client did...          1
# 14  [In today's group all members checked in. The ...          2
# 15  [The group therapy session discussed the impac...          1
# 16  [In IOP group today we used MI to determine va...          1
# 17  [The Noon OP Group is a hybrid, consisting of ...          1
# 18  [AM IOP Group is a hybrid group from 9 am to 1...          1
# 19  [Group Members checked in by detailing their d...          1
# 20  [The group therapy session discussed the effec...          1
# 21  [This group session began with a check-in. Eac...          1
# 22  [Group counselor started the session with a wo...          1
# 23  [This group session began with a check-in. Eac...          1
# 24  [The 12 Noon OP Group is a hybrid group that m...          1
# 25               [Zachary did not attend this group.]          1
# 26  [Your so called unique addicton was discussed,...          1
# 27  [The client shared with the group the positive...          2
# 28  [The group therapy session discussed the topic...          1
# 29  [The Evening OP group meets Mondays and Thursd...          1
# 30  [The client shared that they are looking for a...          1
# 31  [Counselor began the group with a would you ra...          1
# 32  [The AM IOP Group is a hybrid group that meets...          1
# 33  [The Morning IOP group is a hybrid group that ...          1
# 34  [Counselor started the group with a would be r...          1
# 35  [The group therapy session discussed the topic...          1
# 36  [ The AM IOP group is a hybrid group that meet...          1
# 37  [The  12 Noon OP PM Group is a hybrid group th...          1
# 38  [Did not attend group session. Did not attend ...          1
# 39  [Group members each checked in by giving a bri...          1
#
#    therapist_mail
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN

# %%
raw=GroupTherapySession.objects.filter()
raw
# Out:
# <QuerySet [<GroupTherapySession: {"id": "004ba0b9-3d37-4562-8e2f-e2ab087b118b", "group_therapy_group": "Group Test - 556e4a23-8f70-418d-bdfb-cdd6f0dec564", "index": "22", "start_ts": "2023-06-04 13:17:13+00:00"}>, <GroupTherapySession: {"id": "00db3229-1cfb-46fd-a0b3-c767111050d6", "group_therapy_group": "Gaudenzia-Dresher-WG Evening Group - 9ec10cf7-b2e8-4ea4-bb27-31f1000772bb", "index": "10", "start_ts": "2023-09-12 19:56:13+00:00"}>, <GroupTherapySession: {"id": "01d854dd-7302-47d0-8bed-070967cd10a3", "group_therapy_group": "Gaudenzia-Montgomery-Wednesday OP - 28de2a23-1972-4e66-bacc-9d733c27421d", "index": "2", "start_ts": "2023-07-20 21:07:38+00:00"}>, <GroupTherapySession: {"id": "02d06daf-0643-41a5-a1c9-47c22395a26b", "group_therapy_group": "Gaudenzia - Coatesville - Mindfulness Mondays - 923762e8-4907-4913-a6e5-657cc114d6d0", "index": "0", "start_ts": "2023-11-20 16:37:23+00:00"}>, <GroupTherapySession: {"id": "02eccf40-d16f-4bc6-a630-918645d6b161", "group_therapy_group": "Gaudenzia West Shore AM IOP 1890,1891,1892 - 564115d4-bb6e-4f4e-9e58-3876381ffab1", "index": "38", "start_ts": "2023-11-08 13:59:09+00:00"}>, <GroupTherapySession: {"id": "03e21e29-4c59-48b8-b971-710ff76eb47f", "group_therapy_group": "Gaudenzia West Shore PM IOP Group 2940 - 1fa3049d-7e1f-4277-899e-8c6cd49a3c58", "index": "17", "start_ts": "2023-12-11 21:59:43+00:00"}>, <GroupTherapySession: {"id": "04b0f753-3e29-46a2-b779-014a54d3cfeb", "group_therapy_group": "Gaudenzia West Shore AM IOP 1890,1891,1892 - 564115d4-bb6e-4f4e-9e58-3876381ffab1", "index": "0", "start_ts": "2023-07-31 12:46:31+00:00"}>, <GroupTherapySession: {"id": "04f837cb-d171-4c48-90aa-826167461965", "group_therapy_group": "Group Test - 556e4a23-8f70-418d-bdfb-cdd6f0dec564", "index": "23", "start_ts": "2023-06-11 14:12:40+00:00"}>, <GroupTherapySession: {"id": "05728748-b7f3-4ccf-85b3-818de807ff55", "group_therapy_group": "Gaudenzia West Shore PM IOP Group 2940 - 1fa3049d-7e1f-4277-899e-8c6cd49a3c58", "index": "13", "start_ts": "2023-10-23 20:59:49+00:00"}>, <GroupTherapySession: {"id": "06b4ef85-0004-435c-895c-034aed719ee1", "group_therapy_group": "Gaudenzia West Shore AM IOP 1890,1891,1892 - 564115d4-bb6e-4f4e-9e58-3876381ffab1", "index": "0", "start_ts": "2023-08-03 20:07:29+00:00"}>, <GroupTherapySession: {"id": "06d9fedb-281d-4c2e-a39e-c5521eb86bab", "group_therapy_group": "Group Test - 556e4a23-8f70-418d-bdfb-cdd6f0dec564", "index": "50", "start_ts": "2023-12-05 08:31:53+00:00"}>, <GroupTherapySession: {"id": "084f6138-a8a5-4f39-bb86-e0482965b32c", "group_therapy_group": "Gaudenzia West Shore AM IOP 1890,1891,1892 - 564115d4-bb6e-4f4e-9e58-3876381ffab1", "index": "43", "start_ts": "2023-12-01 13:57:48+00:00"}>, <GroupTherapySession: {"id": "09198d04-1948-422f-b9f2-7afb1fb63b9b", "group_therapy_group": "APN Currant Process Group - d1437136-15de-40d3-9186-490a3d1777a9", "index": "1", "start_ts": "2023-12-13 16:57:52+00:00"}>, <GroupTherapySession: {"id": "0b0c4505-8e97-4183-b5e8-bfdcc002f15b", "group_therapy_group": "Gaudenzia-Montgomery-Wednesday OP - 28de2a23-1972-4e66-bacc-9d733c27421d", "index": "27", "start_ts": "2023-10-23 20:54:08+00:00"}>, <GroupTherapySession: {"id": "0c16faaa-f56e-4b01-b9be-4de07b1aba76", "group_therapy_group": "Gaudenzia-Montgomery-Wednesday OP - 28de2a23-1972-4e66-bacc-9d733c27421d", "index": "11", "start_ts": "2023-08-28 20:55:45+00:00"}>, <GroupTherapySession: {"id": "0d1cb3e7-4a68-4b03-93d7-5f3d9b7e867f", "group_therapy_group": "Gaudenzia-Dresher-WG Evening Group - 9ec10cf7-b2e8-4ea4-bb27-31f1000772bb", "index": "17", "start_ts": "2023-11-14 20:57:21+00:00"}>, <GroupTherapySession: {"id": "0d52d8db-971d-418e-a090-fba7485e5674", "group_therapy_group": "Group Test - 556e4a23-8f70-418d-bdfb-cdd6f0dec564", "index": "34", "start_ts": "2023-08-09 11:30:36+00:00"}>, <GroupTherapySession: {"id": "0d8d9838-8447-41f6-959b-6e9a01125bdd", "group_therapy_group": "Gaudenzia - Coatesville - Stages of Change - 41ed0901-304d-4070-bd9d-c0cfdf30d2d2", "index": "0", " ...

# %%
df_raw=pd.DataFrame(raw)
df_raw
# Out:
#                                                      0
# 0    {"id": "004ba0b9-3d37-4562-8e2f-e2ab087b118b",...
# 1    {"id": "00db3229-1cfb-46fd-a0b3-c767111050d6",...
# 2    {"id": "01d854dd-7302-47d0-8bed-070967cd10a3",...
# 3    {"id": "02d06daf-0643-41a5-a1c9-47c22395a26b",...
# 4    {"id": "02eccf40-d16f-4bc6-a630-918645d6b161",...
# ..                                                 ...
# 345  {"id": "fb041f1f-68d8-4f65-9a07-0f4492f0994c",...
# 346  {"id": "fb676117-59e5-49e1-9f63-82b29e2f78fc",...
# 347  {"id": "fc535bbe-920f-44ea-8044-5f01ab63d3e8",...
# 348  {"id": "fde7b2f6-8f9d-44ac-bb8e-6e2a6538035d",...
# 349  {"id": "ffd2470e-2f84-48bf-ac4f-34f8e7b9b115",...
#
# [350 rows x 1 columns]

# %%
def get_group_sessions_chen(start_date, end_date):
    sessions = GroupTherapySession.objects.filter(
        actual_start_ts__gte=start_date,
        actual_start_ts__lt=end_date
    )

    
    g_dict = {}
    for g in sessions:
            patients_list = [patient.name for patient in g.group_therapy_group.patients.all()]
            
            g_dict[g.id] = {
                'individual_session_id': missing_codes,
                'group': g.group_therapy_group,
                'organization':g.group_therapy_group.organization,
                'organization_id':g.group_therapy_group.organization_id,
                'session_start': g.actual_start_ts,
                'session_end': g.actual_end_ts,
                'session duration': (g.actual_end_ts - g.actual_start_ts) if (g.actual_start_ts and g.actual_end_ts) else None,
                'technology': g.technology_used,
                'is_note_confirmed': g.is_note_confirmed,
                'group_therapy_id': g.group_therapy_group_id,
                'is scribe':g.group_therapy_group.is_scribe,
                'ehr':g.group_therapy_group.ehr_group_identifier,
                'saved and signed':g.saved_and_signed,
                'is note confirmed':g.is_note_confirmed,
                'therapists':[therapist.name for therapist in g.group_therapy_group.therapists.all()],
                
                
                'patients': patients_list,
                'number of patients':len(patients_list)
                
             
            }

    group_sessions = pd.DataFrame(g_dict).T
    return group_sessions

df3=get_group_sessions_chen(start_date, end_date)
df3
# Out:
# /home/gabrielkws/gabi_first_venv/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1416: RuntimeWarning: DateTimeField GroupTherapySession.actual_start_ts received a naive datetime (2023-01-21 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/gabrielkws/gabi_first_venv/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1416: RuntimeWarning: DateTimeField GroupTherapySession.actual_start_ts received a naive datetime (2023-12-21 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
#                                                                   individual_session_id  \
# 004ba0b9-3d37-4562-8e2f-e2ab087b118b  {2aa515ca-f6cf-47bb-b69a-5458b14d2eac, 9ef6fb0...
# 00db3229-1cfb-46fd-a0b3-c767111050d6  {2aa515ca-f6cf-47bb-b69a-5458b14d2eac, 9ef6fb0...
# 01d854dd-7302-47d0-8bed-070967cd10a3  {2aa515ca-f6cf-47bb-b69a-5458b14d2eac, 9ef6fb0...
# 02d06daf-0643-41a5-a1c9-47c22395a26b  {2aa515ca-f6cf-47bb-b69a-5458b14d2eac, 9ef6fb0...
# 02eccf40-d16f-4bc6-a630-918645d6b161  {2aa515ca-f6cf-47bb-b69a-5458b14d2eac, 9ef6fb0...
# ...                                                                                 ...
# fa43cecb-e9ae-4ae7-b0a8-f52a44120b89  {2aa515ca-f6cf-47bb-b69a-5458b14d2eac, 9ef6fb0...
# fb041f1f-68d8-4f65-9a07-0f4492f0994c  {2aa515ca-f6cf-47bb-b69a-5458b14d2eac, 9ef6fb0...
# fc535bbe-920f-44ea-8044-5f01ab63d3e8  {2aa515ca-f6cf-47bb-b69a-5458b14d2eac, 9ef6fb0...
# fde7b2f6-8f9d-44ac-bb8e-6e2a6538035d  {2aa515ca-f6cf-47bb-b69a-5458b14d2eac, 9ef6fb0...
# ffd2470e-2f84-48bf-ac4f-34f8e7b9b115  {2aa515ca-f6cf-47bb-b69a-5458b14d2eac, 9ef6fb0...
#
#                                                                                   group  \
# 004ba0b9-3d37-4562-8e2f-e2ab087b118b  Group Test - 556e4a23-8f70-418d-bdfb-cdd6f0dec564
# 00db3229-1cfb-46fd-a0b3-c767111050d6  Gaudenzia-Dresher-WG Evening Group - 9ec10cf7-...
# 01d854dd-7302-47d0-8bed-070967cd10a3  Gaudenzia-Montgomery-Wednesday OP - 28de2a23-1...
# 02d06daf-0643-41a5-a1c9-47c22395a26b  Gaudenzia - Coatesville - Mindfulness Mondays ...
# 02eccf40-d16f-4bc6-a630-918645d6b161  Gaudenzia West Shore AM IOP 1890,1891,1892 - 5...
# ...                                                                                 ...
# fa43cecb-e9ae-4ae7-b0a8-f52a44120b89  Gaudenzia - Coatesville - Stages of Change - 4...
# fb041f1f-68d8-4f65-9a07-0f4492f0994c  Gaudenzia West Shore PM IOP Group 2940 - 1fa30...
# fc535bbe-920f-44ea-8044-5f01ab63d3e8  Gaudenzia-Montgomery-Wednesday OP - 28de2a23-1...
# fde7b2f6-8f9d-44ac-bb8e-6e2a6538035d  Gaudenzia West Shore OP Group 4711 - 2d7a2217-...
# ffd2470e-2f84-48bf-ac4f-34f8e7b9b115  Group Test - 556e4a23-8f70-418d-bdfb-cdd6f0dec564
#
#                                      organization  \
# 004ba0b9-3d37-4562-8e2f-e2ab087b118b   Gaudenzia2
# 00db3229-1cfb-46fd-a0b3-c767111050d6   Gaudenzia2
# 01d854dd-7302-47d0-8bed-070967cd10a3   Gaudenzia2
# 02d06daf-0643-41a5-a1c9-47c22395a26b   Gaudenzia2
# 02eccf40-d16f-4bc6-a630-918645d6b161   Gaudenzia2
# ...                                           ...
# fa43cecb-e9ae-4ae7-b0a8-f52a44120b
[Nicholas Tomczak, Barry Trout, Todd Buckwalte...
# 02eccf40-d16f-4bc6-a630-918645d6b161  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# ...                                                                                 ...
# fa43cecb-e9ae-4ae7-b0a8-f52a44120b89  [Nicholas Tomczak, Barry Trout, Todd Buckwalte...
# fb041f1f-68d8-4f65-9a07-0f4492f0994c  [Elise Narkiewicz, Keri Wintersteen, Laila Eng...
# fc535bbe-920f-44ea-8044-5f01ab63d3e8                   [Lafeeq Bowman, Sherene Phinizy]
# fde7b2f6-8f9d-44ac-bb8e-6e2a6538035d  [Lucy Knoche, Melanie Irwin, Nikki Weir, Joy B...
# ffd2470e-2f84-48bf-ac4f-34f8e7b9b115  [Therapist, eilam, Gaudenzia Test User2, Dana ...
#
#                                                                                patients  \
# 004ba0b9-3d37-4562-8e2f-e2ab087b118b  [000000000, Aaron Test, Admission Test, Alice ...
# 00db3229-1cfb-46fd-a0b3-c767111050d6                                                 []
# 01d854dd-7302-47d0-8bed-070967cd10a3   [Erica Swint, Madison Smith, Rashawn Washington]
# 02d06daf-0643-41a5-a1c9-47c22395a26b                                                 []
# 02eccf40-d16f-4bc6-a630-918645d6b161  [000000000, Adriana Rivera-Colon, Billy Mentze...
# ...                                                                                 ...
# fa43cecb-e9ae-4ae7-b0a8-f52a44120b89  [Bryan Lyons, Charles Gorman, Noel Lourido, Se...
# fb041f1f-68d8-4f65-9a07-0f4492f0994c     [Angela Kline, Bradley Biller, William Nalley]
# fc535bbe-920f-44ea-8044-5f01ab63d3e8   [Erica Swint, Madison Smith, Rashawn Washington]
# fde7b2f6-8f9d-44ac-bb8e-6e2a6538035d  [Adriana Rivera-Colon, Allazzar Cato, Brian Ad...
# ffd2470e-2f84-48bf-ac4f-34f8e7b9b115  [000000000, Aaron Test, Admission Test, Alice ...
#
#                                      number of patients
# 004ba0b9-3d37-4562-8e2f-e2ab087b118b                 18
# 00db3229-1cfb-46fd-a0b3-c767111050d6                  0
# 01d854dd-7302-47d0-8bed-070967cd10a3                  3
# 02d06daf-0643-41a5-a1c9-47c22395a26b                  0
# 02eccf40-d16f-4bc6-a630-918645d6b161                 18
# ...                                                 ...
# fa43cecb-e9ae-4ae7-b0a8-f52a44120b89                  4
# fb041f1f-68d8-4f65-9a07-0f4492f0994c                  3
# fc535bbe-920f-44ea-8044-5f01ab63d3e8                  3
# fde7b2f6-8f9d-44ac-bb8e-6e2a6538035d                 10
# ffd2470e-2f84-48bf-ac4f-34f8e7b9b115                 18
#
# [344 rows x 17 columns]

# %%
df3['group_therapy_id'].nunique()
# Out:
# 14

# %%
def total_info_individual_notes_chen (sessions):

    ind_notes = GenericGroupIndividualReport.objects.filter(group_session_id__in=sessions['group_therapy_id'].unique())


    combined_data=[]
    for s in ind_notes:
        
            session_id=s.group_session_id
            note=get_ind_notes_optimized(s)
            combined_data.append({
                'uuid':session_id,
                'individual_session_notes':note,
                'group_session_id': s.group_session.id,
                #'therapist_mail':s.therapist,
                'therapist_id':s.therapist_id
            })

    combined_df= pd.DataFrame(combined_data)
    #combined_df_filtered = filter_valid_emails(combined_df)
    return combined_df
#combined_dataframe = total_info_individual_notes(sessions_selected)    
#combined_dataframe
df4 = total_info_individual_notes_chen(df3)    
df4
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
ind_notes4 = GenericGroupIndividualReport.objects.filter(group_session_id__in=df3['group_therapy_id'].unique())
ind_notes4
# Out:
# <QuerySet []>

# %%
result_dataframe.to_csv('/home/gabrielkws/Downloads/result_dataframeII.csv')
